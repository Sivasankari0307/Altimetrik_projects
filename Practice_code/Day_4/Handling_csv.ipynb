# %%
import pandas as pd

# %%
# csv file
df = pd.read_csv("sales.csv")
df
# Out:
#          Date Region Product  Units_Sold  Unit_Price
# 0  2024-05-01   East  Laptop           5         700
# 1  2024-05-01   West   Phone          10         300
# 2  2024-05-02   East  Laptop           6         700
# 3  2024-05-02   West   Phone           8         300

# %%
df.head()
# Out:
#          Date Region Product  Units_Sold  Unit_Price
# 0  2024-05-01   East  Laptop           5         700
# 1  2024-05-01   West   Phone          10         300
# 2  2024-05-02   East  Laptop           6         700
# 3  2024-05-02   West   Phone           8         300

# %%
df.to_csv("exported_sales.csv", index=False)

# %%
# excel file
df1 = pd.read_excel("employee_data.xlsx")
df1
# Out:
#    Emp_ID     Name Department
# 0     101    Alice         HR
# 1     102      Bob    Finance
# 2     103  Charlie         IT
# 3     104    David      Sales

# %%
df1.to_excel("exported_employee_data.xlsx", sheet_name="Employee_Info")

# %%
# read csv and export to excel
df3 = pd.read_csv("sales.csv")
df3
# Out:
#          Date Region Product  Units_Sold  Unit_Price
# 0  2024-05-01   East  Laptop           5         700
# 1  2024-05-01   West   Phone          10         300
# 2  2024-05-02   East  Laptop           6         700
# 3  2024-05-02   West   Phone           8         300

# %%
df3["Revenue"] = df3["Units_Sold"] * df3["Unit_Price"]
df3
# Out:
#          Date Region Product  Units_Sold  Unit_Price  Revenue
# 0  2024-05-01   East  Laptop           5         700     3500
# 1  2024-05-01   West   Phone          10         300     3000
# 2  2024-05-02   East  Laptop           6         700     4200
# 3  2024-05-02   West   Phone           8         300     2400

# %%
df3.to_excel("exported_csv_excel.xlsx", index=False)
